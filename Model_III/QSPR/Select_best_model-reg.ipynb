# %%
import pandas as pd

# Define the path to the Excel file
file_path = '../Data/Quality_ee_15_.xlsx'

# Define the sheets and metrics
sheets = ["MLR", "DT", "RF", "KNN", "SVM"]
metrics = ['Training data R^2 score', 'Test data R^2 score', 'Training RMSE', 'Test RMSE']
number_of_features = 10
# Initialize a dictionary to store the best models
best_models = {}

# Iterate through each sheet to find the best model
for sheet in sheets:
    # Read the data from the current sheet
    df = pd.read_excel(file_path, sheet_name=sheet)
    df_filtered = df[df['Number of features'] < number_of_features]
    # Filter the DataFrame based on the criteria
    # The model must have higher training parameters than test parameters
    filtered_df = df_filtered[(df_filtered['Training data R^2 score'] > df_filtered['Test data R^2 score']) & 
                     (df_filtered['Training RMSE'] < df_filtered['Test RMSE']) & 
                              (df_filtered['Test data R^2 score'] > 0.36)]
    
    if not filtered_df.empty:
        # Find the row with the maximum Test Accuracy
        best_model = filtered_df.loc[filtered_df['Test data R^2 score'].idxmax()]
        best_model = filtered_df.loc[filtered_df['Correlation threshold'].idxmax()]
        best_models[sheet] = best_model

# Convert the results to a DataFrame for better visualization
best_models_df = pd.DataFrame.from_dict(best_models, orient='index')

# Print the best models for each method
print("Best Models for Each Method:")
best_models_df
# Out:
# Best Models for Each Method:
#     Unnamed: 0  Correlation threshold  Training data R^2 score
# DT       225.0                   0.40                 0.467051  \
# RF       177.0                   0.41                 0.779434
#
#     Test data R^2 score  Training RMSE  Test RMSE  Number of features
# DT             0.368890      24.574485  30.387745                 3.0  \
# RF             0.391435      15.809250  29.840049                 2.0
#
#     Depth number  Number of estimators
# DT           3.0                   NaN
# RF           NaN                   8.0

# %%
#best_models_df['Test data R^2 score']['DT']

# %%
try:
    import numpy as np
    print("The correlation coefficient for test data equals: "+str(np.sqrt(best_models_df['Test data R^2 score']['DT'])))
    print("The correlation coefficient for training data equals: "+str(np.sqrt(best_models_df['Training data R^2 score']['DT'])))
except:
    print("Error gathering the data...")
# Out:
# The correlation coefficient for test data equals: 0.6073630644217882
# The correlation coefficient for training data equals: 0.6834111438288402

# %%
import pandas as pd

# Define the path to the Excel file
file_path = '../Data/Quality_ee_28_.xlsx'

# Define the sheets and metrics
sheets = ["MLR", "DT", "RF", "KNN", "SVM"]
metrics = ['Training data R^2 score', 'Test data R^2 score', 'Training RMSE', 'Test RMSE']
number_of_features = 10
# Initialize a dictionary to store the best models
best_models = {}

# Iterate through each sheet to find the best model
for sheet in sheets:
    # Read the data from the current sheet
    df = pd.read_excel(file_path, sheet_name=sheet)
    df_filtered = df[df['Number of features'] < number_of_features]
    # Filter the DataFrame based on the criteria
    # The model must have higher training parameters than test parameters
    filtered_df = df_filtered[(df_filtered['Training data R^2 score'] > df_filtered['Test data R^2 score']) & 
                     (df_filtered['Training RMSE'] < df_filtered['Test RMSE']) & 
                              (df_filtered['Test data R^2 score'] > 0.36)]
    
    if not filtered_df.empty:
        # Find the row with the maximum Test Accuracy
        best_model = filtered_df.loc[filtered_df['Test data R^2 score'].idxmax()]
        best_model = filtered_df.loc[filtered_df['Correlation threshold'].idxmax()]
        best_models[sheet] = best_model

# Convert the results to a DataFrame for better visualization
best_models_df = pd.DataFrame.from_dict(best_models, orient='index')

# Print the best models for each method
print("Best Models for Each Method:")
best_models_df
# Out:
# Best Models for Each Method:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd

# Define the path to the Excel file
file_path = '../Data/Quality_ee_42_.xlsx'

# Define the sheets and metrics
sheets = ["MLR", "DT", "RF", "KNN", "SVM"]
metrics = ['Training data R^2 score', 'Test data R^2 score', 'Training RMSE', 'Test RMSE']
number_of_features = 10
# Initialize a dictionary to store the best models
best_models = {}

# Iterate through each sheet to find the best model
for sheet in sheets:
    # Read the data from the current sheet
    df = pd.read_excel(file_path, sheet_name=sheet)
    df_filtered = df[df['Number of features'] < number_of_features]
    # Filter the DataFrame based on the criteria
    # The model must have higher training parameters than test parameters
    filtered_df = df_filtered[(df_filtered['Training data R^2 score'] > df_filtered['Test data R^2 score']) & 
                     (df_filtered['Training RMSE'] < df_filtered['Test RMSE']) & 
                              (df_filtered['Test data R^2 score'] > 0.36)]
    
    if not filtered_df.empty:
        # Find the row with the maximum Test Accuracy
        best_model = filtered_df.loc[filtered_df['Test data R^2 score'].idxmax()]
        best_model = filtered_df.loc[filtered_df['Correlation threshold'].idxmax()]
        best_models[sheet] = best_model

# Convert the results to a DataFrame for better visualization
best_models_df = pd.DataFrame.from_dict(best_models, orient='index')

# Print the best models for each method
print("Best Models for Each Method:")
best_models_df
# Out:
# Best Models for Each Method:
#     Unnamed: 0  Correlation threshold  Training data R^2 score
# DT       256.0                   0.41                 0.837211  \
# RF       171.0                   0.41                 0.714628
#
#     Test data R^2 score  Training RMSE  Test RMSE  Number of features
# DT             0.424843      13.633313  28.710981                 2.0  \
# RF             0.392727      18.050738  29.501695                 2.0
#
#     Depth number  Number of estimators
# DT           6.0                   NaN
# RF           NaN                   2.0

# %%
import pandas as pd

# Define the path to the Excel file
file_path = '../Data/Quality_ee_42_.xlsx'

# Define the sheets and metrics
sheets = ["MLR", "DT", "RF", "KNN", "SVM"]
metrics = ['Training data R^2 score', 'Test data R^2 score', 'Training RMSE', 'Test RMSE']
number_of_features = 10
# Initialize a dictionary to store the best models
best_models = {}

# Iterate through each sheet to find the best model
for sheet in sheets:
    # Read the data from the current sheet
    df = pd.read_excel(file_path, sheet_name=sheet)
    df_filtered = df[df['Number of features'] < number_of_features]
    # Filter the DataFrame based on the criteria
    # The model must have higher training parameters than test parameters
    filtered_df = df_filtered[(df_filtered['Training data R^2 score'] > df_filtered['Test data R^2 score']) & 
                     (df_filtered['Training RMSE'] < df_filtered['Test RMSE']) & 
                              (df_filtered['Test data R^2 score'] > 0.60)]
    
    if not filtered_df.empty:
        # Find the row with the maximum Test Accuracy
        best_model = filtered_df.loc[filtered_df['Test data R^2 score'].idxmax()]
        best_model = filtered_df.loc[filtered_df['Correlation threshold'].idxmax()]
        best_models[sheet] = best_model

# Convert the results to a DataFrame for better visualization
best_models_df = pd.DataFrame.from_dict(best_models, orient='index')

# Print the best models for each method
print("Best Models for Each Method:")
best_models_df
# Out:
# Best Models for Each Method:
#     Unnamed: 0  Correlation threshold  Training data R^2 score
# RF       173.0                   0.41                 0.756246  \
#
#     Test data R^2 score  Training RMSE  Test RMSE  Number of features
# RF             0.679204       16.68265  21.442219                 2.0  \
#
#     Number of estimators
# RF                   4.0

# %%
import numpy as np
np.sqrt(0.621787)
# Out:
# 0.7885347170543603

# %%
np.sqrt(0.864952)
# Out:
# 0.9300279565690486

# %%
try:
    import numpy as np
    print("The correlation coefficient for test data equals: "+str(np.sqrt(best_models_df['Test data R^2 score']['RF'])))
    print("The correlation coefficient for training data equals: "+str(np.sqrt(best_models_df['Training data R^2 score']['RF'])))
except:
    print("Error gathering the data...")
# Out:
# The correlation coefficient for test data equals: 0.6266791970604704
# The correlation coefficient for training data equals: 0.845356686637706

# %%
import pandas as pd

# Define the path to the Excel file
file_path = '../Data/Quality_ee_15_.xlsx'

# Define the sheets and metrics
sheets = ["MLR", "DT", "RF", "KNN", "SVM"]
metrics = ['Training data R^2 score', 'Test data R^2 score', 'Training RMSE', 'Test RMSE']
number_of_features = 10
# Initialize a dictionary to store the best models
best_models = {}

# Iterate through each sheet to find the best model
for sheet in sheets:
    # Read the data from the current sheet
    df = pd.read_excel(file_path, sheet_name=sheet)
    df_filtered = df[df['Number of features'] < number_of_features]
    # Filter the DataFrame based on the criteria
    # The model must have higher training parameters than test parameters
    filtered_df = df_filtered[(df_filtered['Test data R^2 score'] > 0.36)]
    
    if not filtered_df.empty:
        # Find the row with the maximum Test Accuracy
        best_model = filtered_df.loc[filtered_df['Test data R^2 score'].idxmax()]
        best_model = filtered_df.loc[filtered_df['Correlation threshold'].idxmax()]
        best_models[sheet] = best_model

# Convert the results to a DataFrame for better visualization
best_models_df = pd.DataFrame.from_dict(best_models, orient='index')

# Print the best models for each method
print("Best Models for Each Method:")
best_models_df
# Out:
# Best Models for Each Method:
#      Unnamed: 0  Correlation threshold  Training data R^2 score
# MLR         9.0                   0.41                 0.270662  \
# DT        252.0                   0.41                 0.318733
# RF        177.0                   0.41                 0.779434
# KNN        42.0                   0.38                 0.377202
# SVM       336.0                   0.41                 0.066226
#
#      Test data R^2 score  Training RMSE  Test RMSE  Number of features
# MLR             0.578568      28.747894  24.831871                 2.0  \
# DT              0.530244      27.784337  26.216938                 2.0
# RF              0.391435      15.809250  29.840049                 2.0
# KNN             0.413133      26.565332  29.303252                 5.0
# SVM             0.384638      32.528372  30.006213                 2.0
#
#      Depth number  Number of estimators  Number of neighbors    C  Gamma
# MLR           NaN                   NaN                  NaN  NaN    NaN  \
# DT            2.0                   NaN                  NaN  NaN    NaN
# RF            NaN                   8.0                  NaN  NaN    NaN
# KNN           NaN                   NaN                  3.0  NaN    NaN
# SVM           NaN                   NaN                  NaN  1.0    1.0
#
#      Kernel
# MLR     NaN
# DT      NaN
# RF      NaN
# KNN     NaN
# SVM  linear

# %%
import pandas as pd

# Define the path to the Excel file
file_path = '../Data/Quality_ee_28_.xlsx'

# Define the sheets and metrics
sheets = ["MLR", "DT", "RF", "KNN", "SVM"]
metrics = ['Training data R^2 score', 'Test data R^2 score', 'Training RMSE', 'Test RMSE']
number_of_features = 10
# Initialize a dictionary to store the best models
best_models = {}

# Iterate through each sheet to find the best model
for sheet in sheets:
    # Read the data from the current sheet
    df = pd.read_excel(file_path, sheet_name=sheet)
    df_filtered = df[df['Number of features'] < number_of_features]
    # Filter the DataFrame based on the criteria
    # The model must have higher training parameters than test parameters
    filtered_df = df_filtered[(df_filtered['Test data R^2 score'] > 0.36)]
    
    if not filtered_df.empty:
        # Find the row with the maximum Test Accuracy
        best_model = filtered_df.loc[filtered_df['Test data R^2 score'].idxmax()]
        best_model = filtered_df.loc[filtered_df['Correlation threshold'].idxmax()]
        best_models[sheet] = best_model

# Convert the results to a DataFrame for better visualization
best_models_df = pd.DataFrame.from_dict(best_models, orient='index')

# Print the best models for each method
print("Best Models for Each Method:")
best_models_df
# Out:
# Best Models for Each Method:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd

# Define the path to the Excel file
file_path = '../Data/Quality_ee_42_.xlsx'

# Define the sheets and metrics
sheets = ["MLR", "DT", "RF", "KNN", "SVM"]
metrics = ['Training data R^2 score', 'Test data R^2 score', 'Training RMSE', 'Test RMSE']
number_of_features = 10
# Initialize a dictionary to store the best models
best_models = {}

# Iterate through each sheet to find the best model
for sheet in sheets:
    # Read the data from the current sheet
    df = pd.read_excel(file_path, sheet_name=sheet)
    df_filtered = df[df['Number of features'] < number_of_features]
    # Filter the DataFrame based on the criteria
    # The model must have higher training parameters than test parameters
    filtered_df = df_filtered[(df_filtered['Test data R^2 score'] > 0.36)]
    
    if not filtered_df.empty:
        # Find the row with the maximum Test Accuracy
        best_model = filtered_df.loc[filtered_df['Test data R^2 score'].idxmax()]
        best_model = filtered_df.loc[filtered_df['Correlation threshold'].idxmax()]
        best_models[sheet] = best_model

# Convert the results to a DataFrame for better visualization
best_models_df = pd.DataFrame.from_dict(best_models, orient='index')

# Print the best models for each method
print("Best Models for Each Method:")
best_models_df
# Out:
# Best Models for Each Method:
#      Unnamed: 0  Correlation threshold  Training data R^2 score
# MLR         9.0                   0.41                 0.286688  \
# DT        252.0                   0.41                 0.331910
# RF        171.0                   0.41                 0.714628
# KNN        29.0                   0.36                 0.384326
# SVM       348.0                   0.41                 0.232669
#
#      Test data R^2 score  Training RMSE  Test RMSE  Number of features
# MLR             0.535456      28.538356  25.802896                 2.0  \
# DT              0.492620      27.618924  26.966315                 2.0
# RF              0.392727      18.050738  29.501695                 2.0
# KNN             0.394916      26.513354  29.448472                 7.0
# SVM             0.566659      29.599238  24.921249                 2.0
#
#      Depth number  Number of estimators  Number of neighbors     C  Gamma
# MLR           NaN                   NaN                  NaN   NaN    NaN  \
# DT            2.0                   NaN                  NaN   NaN    NaN
# RF            NaN                   2.0                  NaN   NaN    NaN
# KNN           NaN                   NaN                  4.0   NaN    NaN
# SVM           NaN                   NaN                  NaN  10.0    1.0
#
#      Kernel
# MLR     NaN
# DT      NaN
# RF      NaN
# KNN     NaN
# SVM  linear

# %%
import pandas as pd

# Define the path to the Excel file
file_path = '../Data/Quality_ee_42_.xlsx'

# Define the sheets and metrics
sheets = ["MLR", "DT", "RF", "KNN", "SVM"]
metrics = ['Training data R^2 score', 'Test data R^2 score', 'Training RMSE', 'Test RMSE']
number_of_features = 10

# Initialize a dictionary to store the best models
best_models = {}

# Iterate through each sheet to find the best model
for sheet in sheets:
    # Read the data from the current sheet
    df = pd.read_excel(file_path, sheet_name=sheet)
    df_filtered = df[df['Number of features'] < number_of_features]
    
    # Filter the DataFrame based on the criteria
    filtered_df = df_filtered[df_filtered['Test data R^2 score'] > 0.36]
    
    if not filtered_df.empty:
        # Find the row with the maximum Test data R^2 score
        best_model = filtered_df.loc[filtered_df['Test data R^2 score'].idxmax()]
        best_models[sheet] = best_model
    else:
        print(f"No models in sheet {sheet} meet the criteria (Test data R^2 score > 0.x).")

# Convert the results to a DataFrame for better visualization
best_models_df = pd.DataFrame.from_dict(best_models, orient='index')

# Print the best models for each method
print("Best Models for Each Method:")
best_models_df
# Out:
# Best Models for Each Method:
#      Unnamed: 0  Correlation threshold  Training data R^2 score
# MLR         9.0                   0.41                 0.286688  \
# DT        252.0                   0.41                 0.331910
# RF        173.0                   0.41                 0.756246
# KNN        32.0                   0.36                 0.237259
# SVM       348.0                   0.41                 0.232669
#
#      Test data R^2 score  Training RMSE  Test RMSE  Number of features
# MLR             0.535456      28.538356  25.802896                 2.0  \
# DT              0.492620      27.618924  26.966315                 2.0
# RF              0.679204      16.682650  21.442219                 2.0
# KNN             0.445772      29.510588  28.183763                 7.0
# SVM             0.566659      29.599238  24.921249                 2.0
#
#      Depth number  Number of estimators  Number of neighbors     C  Gamma
# MLR           NaN                   NaN                  NaN   NaN    NaN  \
# DT            2.0                   NaN                  NaN   NaN    NaN
# RF            NaN                   4.0                  NaN   NaN    NaN
# KNN           NaN                   NaN                  7.0   NaN    NaN
# SVM           NaN                   NaN                  NaN  10.0    1.0
#
#      Kernel
# MLR     NaN
# DT      NaN
# RF      NaN
# KNN     NaN
# SVM  linear
